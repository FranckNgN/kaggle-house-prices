# %% [markdown]
# # This is the ship log of this project

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Cleaning
# outlier, missing values + MB use logsaleprice before any of this

# %% [markdown]
# ### Data Engineering

# %% [markdown]
# ### Feature Engineering
# This has not been done yet and will be done when all models have been built and running. This is for optimisation

# %% [markdown]
# ### Skew and kurtosis
# transform using log sale price

# %% [markdown]
# ### Scaling
# Looking at continuous numeric values, we are normalizing it

# %% [markdown]
# ### Categorial Encoding

# %% [markdown]
# ## Models

# %% [markdown]
# ### L1

# %% [markdown]
# #### Linear Regresion

# %% [markdown]
# #### Ridge

# %% [markdown]
# ### L2

# %% [markdown]
# #### Lasso

# %% [markdown]
# #### Elastic Net

# %% [markdown]
# ### GBM

# %% [markdown]
# ### Blending

# %% [markdown]
# ### Stacking

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# ### Hyper param tuning and optimisation

# %% [markdown]
# Cross-validated OOF predictions
